# %%
import os
import csv
import pandas as pd

filelist=os.listdir("C:/Users/Hiroka/Downloads/sta160/Dataset/csv/4_rankings")
dfs = [pd.read_csv("C:/Users/Hiroka/Downloads/sta160/Dataset/csv/4_rankings/"+f, index_col=False,  names=["week_title",
"week_year",
"week_month",
"week_day",
"rank_text",
"rank_number",
"move_positions",
"move_direction",
"player_age",
"ranking_points",
"tourneys_played",
"player_url",
"player_slug",
"player_id"],header=None) for f in filelist if f.endswith('csv')]
ranks = pd.concat(dfs, axis=0, join='outer',ignore_index=True).sort_index()
ranks
# Out:
#          week_title  week_year  week_month  week_day rank_text  rank_number  \
# 0        1973.12.14       1973          12        14         1            1
# 1        1973.12.14       1973          12        14         2            2
# 2        1973.12.14       1973          12        14         3            3
# 3        1973.12.14       1973          12        14         4            4
# 4        1973.12.14       1973          12        14         5            5
# 5        1973.12.14       1973          12        14         6            6
# 6        1973.12.14       1973          12        14         7            7
# 7        1973.12.14       1973          12        14         8            8
# 8        1973.12.14       1973          12        14         9            9
# 9        1973.12.14       1973          12        14        10           10
# 10       1973.12.14       1973          12        14        11           11
# ...

# %%
top10=ranks[ranks["rank_number"]<=5]
top10=top10[["week_title","week_year","rank_number","player_slug","player_id"]]
top10['week_title'] = top10['week_title'].apply(lambda x: pd.to_datetime(str(x), format='%Y.%m.%d'))
top10['week_year']=top10['week_year'].astype(str).str[2]
top10
# Out:
#         week_title week_year  rank_number     player_slug player_id
# 0       1973-12-14         7            1    ilie-nastase      n008
# 1       1973-12-14         7            2   john-newcombe      n044
# 2       1973-12-14         7            3   jimmy-connors      c044
# 3       1973-12-14         7            4       tom-okker      o032
# 4       1973-12-14         7            5      stan-smith      s060
# 235     1973-11-26         7            1    ilie-nastase      n008
# 236     1973-11-26         7            2   john-newcombe      n044
# 237     1973-11-26         7            3   jimmy-connors      c044
# 238     1973-11-26         7            4       tom-okker      o032
# 239     1973-11-26         7            5      stan-smith      s060
# 468     1973-10-31         7            1    ilie-nastase      n008
# 469     1973-10-31         7            2   john-newcombe      n044
# 470     1973-10-31         7            3  manuel-orantes      o017
# ...

# %%
from plotnine import *
import plotnine as p9

# %%
(p9.ggplot(top10, aes(x='week_title',y='rank_number',group='player_slug')) +
geom_line(aes(color='player_slug'))+theme(figure_size = (11,8),legend_position="bottom",axis_text_x=element_text(rotation=45, hjust=1)))+facet_wrap('~ week_year',scales = "free")
# Out:
# <ggplot: (-9223371913975550197)>

# %%
big4=ranks[ranks["player_slug"].isin(["novak-djokovic", "rafael-nadal","roger-federer","andy-murray"])]
big4=big4[["week_title","week_year","rank_number","player_slug","player_id"]]
big4['week_title'] = big4['week_title'].apply(lambda x: pd.to_datetime(str(x), format='%Y.%m.%d'))
big4
# Out:
#         week_title  week_year  rank_number     player_slug player_id
# 766192  1997-12-29       1997          704   roger-federer      f324
# 767785  1997-12-22       1997          704   roger-federer      f324
# 769378  1997-12-15       1997          704   roger-federer      f324
# 770965  1997-12-08       1997          698   roger-federer      f324
# 772542  1997-12-01       1997          699   roger-federer      f324
# 774100  1997-11-24       1997          692   roger-federer      f324
# 775661  1997-11-17       1997          700   roger-federer      f324
# 777310  1997-11-10       1997          799   roger-federer      f324
# 778867  1997-11-03       1997          802   roger-federer      f324
# 780422  1997-10-27       1997          806   roger-federer      f324
# 781975  1997-10-20       1997          803   roger-federer      f324
# 783527  1997-10-13       1997          800   roger-federer      f324
# 785084  1997-10-06       1997          799   roger-federer      f324
# ...

# %%
(p9.ggplot(big4, aes(x='week_title',y='rank_number',group='player_slug')) +
geom_line(aes(color='player_slug'))+theme(figure_size = (11,8),legend_position="bottom",axis_text_x=element_text(rotation=45, hjust=1))+
ggtitle('Big 4 Rankings Timeline') + 
xlab('Month') + 
ylab('Rank'))+facet_wrap('~ week_year',scales = "free")+ scale_y_reverse()
# Out:
# <ggplot: (-9223371913978781373)>
